# %%
import pandas as pd
import numpy as np
from statsmodels.stats.proportion import proportion_confint

# %%
np = pd.read_csv('/Users/ASUS/Desktop/Pertussis data analysis/np.csv')
np.head()
np.shape
np['age_group'] = pd.cut(  #grouped into age groups
    np['infant_age'],
    bins=[0, 29, 60, np['infant_age'].max()],
    labels=['Neonates', '1-2 months', '2+ months'],
    right=False  # include left edge, exclude right (0-28 days, 29-59 days, 60+ days)
)
np.head()
np['ct_mean'] = pd.to_numeric(np['ct_mean'], errors='coerce')
np = np[(np['parent'] == False)][["subject_id", 'parent', 'ct.detect', 'ct_mean', 'infant_age', 'age_group', "wp"]]
np.head()
#if the infant was vaccinated on the previous visit
np["dose_prev"] = np.groupby("subject_id")["wp"].shift(1).fillna(0).astype(bool)
np.loc[:, "nshot_prev"] = np.groupby("subject_id")["dose_prev"].cumsum()
np.head()
print(np.columns.tolist())
np = np.sort_values(['subject_id', 'infant_age']).copy()
np['wp'] = np['wp'].astype(bool)
g = np.groupby('subject_id')

# the first infant_age where wp is True. If no True exists, returns NaN.
first_wp_age_by_subject = g.apply(
    lambda x: x.loc[x['wp'], 'infant_age'].iloc[0] if x['wp'].any() else float('nan'), include_groups=False)

# Adds a column giving each subject’s first wp age for all their rows.
np['ref_age'] = np['subject_id'].map(first_wp_age_by_subject)

# running total of wp within each subject. All rows after the first True will have positive values.
np['post_first_wp'] = g['wp'].cummax()

# Calculates the difference between current age and first wp age, but only for rows after that first event
np['days_since_first_wp'] = (np['infant_age'] - np['ref_age']).where(np['post_first_wp'])

np.drop(columns=['ref_age', 'post_first_wp'], inplace=True)
# Out:
# ['subject_id', 'parent', 'ct.detect', 'ct_mean', 'infant_age', 'age_group', 'wp', 'dose_prev', 'nshot_prev']

# %%
np["Unvaccinated"] = (np["nshot_prev"] == 0) | ((np["nshot_prev"] == 1) & (np["days_since_first_wp"] < 14))
np["Recently Vaccinated"] = ((np["nshot_prev"] >= 1) & (np["days_since_first_wp"] >= 14) &(np["days_since_first_wp"] <= 28))
np["Vaccinated"] =  ((np["nshot_prev"] >= 1) & (np["days_since_first_wp"] > 28))
np.head(10)
# Out:
#    subject_id  parent  ct.detect  ct_mean  infant_age   age_group     wp  \
# 0           4   False      False      NaN           7    Neonates  False
# 1           4   False      False      NaN          21    Neonates  False
# 2           4   False      False      NaN          42  1-2 months   True
# 3           4   False      False      NaN          56  1-2 months  False
# 4           4   False      False      NaN          63   2+ months  False
# 5           4   False      False      NaN          72   2+ months   True
# 6           4   False      False      NaN          90   2+ months  False
# 7           4   False      False      NaN          96   2+ months  False
# 8           4   False      False      NaN         110   2+ months   True
# 9           6   False      False      NaN           7    Neonates  False
#
#    dose_prev  nshot_prev  days_since_first_wp  Unvaccinated  \
# 0      False           0                  NaN          True
# 1      False           0                  NaN          True
# 2      False           0                  0.0          True
# 3       True           1                 14.0         False
# 4      False           1                 21.0         False
# 5      False           1                 30.0         False
# 6       True           2                 48.0         False
# 7      False           2                 54.0         False
# 8      False           2                 68.0         False
# 9      False           0                  NaN          True
#
#    Recently Vaccinated  Vaccinated
# 0                False       False
# 1                False       False
# 2                False       False
# 3                 True       False
# 4                 True       False
# 5                False        True
# 6                False        True
# 7                False        True
# 8                False        True
# 9                False       False

# %%
subject_df = pd.read_csv('/Users/ASUS/Downloads/subject.csv')
subject_df.head(10)
# Out:
#    subject_id  parent  n.visit  n.unsched  age.min       begin         end  \
# 0           3   False        2          0        4  2015-03-02  2015-03-17
# 1           3    True        2          0        4  2015-03-02  2015-03-17
# 2           4   False        9          2        7  2015-03-03  2015-06-14
# 3           4    True        9          2        7  2015-03-03  2015-06-14
# 4           5   False        1          0       10  2015-03-02  2015-03-02
# 5           5    True        1          0       10  2015-03-02  2015-03-02
# 6           6   False        8          1        7  2015-03-02  2015-06-03
# 7           6    True        8          1        7  2015-03-02  2015-06-03
# 8           7   False        7          0        7  2015-03-06  2015-06-12
# 9           7    True        7          0        7  2015-03-06  2015-06-12
#
#    duration  nshot
# 0        15    0.0
# 1        15    NaN
# 2       103    3.0
# 3       103    NaN
# 4         0    0.0
# 5         0    NaN
# 6        93    2.0
# 7        93    NaN
# 8        98    2.0
# 9        98    NaN

# %%
filtered_df = subject_df[subject_df['parent'] == False]

final_df = filtered_df[['subject_id', "nshot"]]
final_df.head()
# Out:
#    subject_id  nshot
# 0           3    0.0
# 2           4    3.0
# 4           5    0.0
# 6           6    2.0
# 8           7    2.0

# %%
efi = pd.read_csv('/Users/ASUS/Downloads/efi.csv')
efi.head()
# Out:
#    subject_id  parent  n.sample  n.detect  n.nose.cough  n.sick  n.abx  \
# 0           4   False         9         0             3       2      2
# 1           6   False         8         3             2       1      2
# 2           7   False         7         0             2       1      1
# 3          11   False         7         0             1       0      0
# 4          12   False         7         0             0       0      0
#
#           fsymptom efi.strength      efi
# 0  Moderate/Severe          NaN  0.00000
# 1  Moderate/Severe       Strong  0.73009
# 2  Moderate/Severe          NaN  0.00000
# 3          Minimal          NaN  0.00000
# 4              NaN          NaN  0.00000

# %%
efi[efi["subject_id"] == 26]
# Out:
#       subject_id  parent  n.sample  n.detect  n.nose.cough  n.sick  n.abx  \
# 16            26   False         7         1             1       0      0
# 1336          26    True         7         0             0       0      0
#
#      fsymptom efi.strength      efi
# 16    Minimal         Weak  0.49911
# 1336      NaN          NaN  0.00000

# %%
efi_df = efi.loc[efi["parent"] == False].copy()

# Fill missing values safely
efi_df.loc[:, "fsymptom"] = efi_df["fsymptom"].fillna("None")
efi_df.loc[:, "efi.strength"] = efi_df["efi.strength"].fillna("None")

efi_df.head()
# Out:
#    subject_id  parent  n.sample  n.detect  n.nose.cough  n.sick  n.abx  \
# 0           4   False         9         0             3       2      2
# 1           6   False         8         3             2       1      2
# 2           7   False         7         0             2       1      1
# 3          11   False         7         0             1       0      0
# 4          12   False         7         0             0       0      0
#
#           fsymptom efi.strength      efi
# 0  Moderate/Severe         None  0.00000
# 1  Moderate/Severe       Strong  0.73009
# 2  Moderate/Severe         None  0.00000
# 3          Minimal         None  0.00000
# 4             None         None  0.00000

# %%
merged_efi = efi_df.merge(final_df, on="subject_id", how="left")
merged_efi.head()
# Out:
#    subject_id  parent  n.sample  n.detect  n.nose.cough  n.sick  n.abx  \
# 0           4   False         9         0             3       2      2
# 1           6   False         8         3             2       1      2
# 2           7   False         7         0             2       1      1
# 3          11   False         7         0             1       0      0
# 4          12   False         7         0             0       0      0
#
#           fsymptom efi.strength      efi  nshot
# 0  Moderate/Severe         None  0.00000    3.0
# 1  Moderate/Severe       Strong  0.73009    2.0
# 2  Moderate/Severe         None  0.00000    2.0
# 3          Minimal         None  0.00000    3.0
# 4             None         None  0.00000    3.0

# %%
efi_strongweak= merged_efi.loc[merged_efi['efi.strength'].isin(['Strong', 'Weak']), ['subject_id', 'efi.strength']]
efi_strongweak.shape
# Out:
# (454, 2)

# %%
efi_strong= merged_efi.loc[merged_efi['efi.strength'].isin(['Strong']), ['subject_id', 'efi.strength']]
efi_strong.shape
# Out:
# (177, 2)

# %%
list_efistrong = efi_strong['subject_id'].tolist()
print(list_efistrong)
# Out:
# [6, 15, 20, 70, 72, 95, 96, 112, 115, 126, 130, 132, 140, 152, 166, 170, 197, 198, 199, 222, 233, 235, 242, 243, 246, 249, 251, 255, 260, 268, 269, 273, 279, 298, 341, 342, 344, 346, 347, 349, 350, 353, 355, 357, 358, 365, 367, 369, 375, 378, 384, 386, 387, 389, 398, 403, 405, 414, 419, 424, 425, 428, 429, 434, 436, 445, 447, 449, 456, 462, 463, 466, 468, 472, 474, 476, 479, 480, 482, 484, 488, 498, 501, 504, 514, 516, 518, 527, 534, 535, 537, 542, 544, 553, 556, 563, 565, 570, 572, 573, 575, 576, 579, 589, 599, 603, 610, 627, 639, 643, 644, 646, 649, 652, 660, 665, 674, 677, 683, 685, 687, 689, 691, 692, 697, 700, 714, 716, 720, 727, 728, 729, 733, 735, 738, 739, 741, 742, 745, 748, 752, 762, 785, 801, 808, 818, 828, 868, 877, 882, 890, 898, 910, 912, 920, 928, 949, 962, 995, 1004, 1047, 1089, 1126, 1131, 1161, 1162, 1219, 1265, 1295, 1332, 1355, 1374, 1430, 1560, 1605, 1852, 1908]

# %%
final = efi_df.merge(np, on='subject_id', how='left')
final.head()
# Out:
#    subject_id  parent_x  n.sample  n.detect  n.nose.cough  n.sick  n.abx  \
# 0           4     False         9         0             3       2      2
# 1           4     False         9         0             3       2      2
# 2           4     False         9         0             3       2      2
# 3           4     False         9         0             3       2      2
# 4           4     False         9         0             3       2      2
#
#           fsymptom efi.strength  efi  ...  ct_mean  infant_age   age_group  \
# 0  Moderate/Severe         None  0.0  ...      NaN           7    Neonates
# 1  Moderate/Severe         None  0.0  ...      NaN          21    Neonates
# 2  Moderate/Severe         None  0.0  ...      NaN          42  1-2 months
# 3  Moderate/Severe         None  0.0  ...      NaN          56  1-2 months
# 4  Moderate/Severe         None  0.0  ...      NaN          63   2+ months
#
#       wp dose_prev  nshot_prev  days_since_first_wp  Unvaccinated  \
# 0  False     False           0                  NaN          True
# 1  False     False           0                  NaN          True
# 2   True     False           0                  0.0          True
# 3  False      True           1                 14.0         False
# 4  False     False           1                 21.0         False
#
#    Recently Vaccinated  Vaccinated
# 0                False       False
# 1                False       False
# 2                False       False
# 3                 True       False
# 4                 True       False
#
# [5 rows x 22 columns]

# %%
final = final.drop(columns=['n.sample', 'n.detect', 'n.nose.cough', 'n.sick', 'n.abx', 'dose_prev', 'nshot_prev', 'ct.detect', 'parent_x', "parent_y","efi","wp"])
final.head(20)
# Out:
#     subject_id         fsymptom efi.strength  ct_mean  infant_age   age_group  \
# 0            4  Moderate/Severe         None      NaN           7    Neonates
# 1            4  Moderate/Severe         None      NaN          21    Neonates
# 2            4  Moderate/Severe         None      NaN          42  1-2 months
# 3            4  Moderate/Severe         None      NaN          56  1-2 months
# 4            4  Moderate/Severe         None      NaN          63   2+ months
# 5            4  Moderate/Severe         None      NaN          72   2+ months
# 6            4  Moderate/Severe         None      NaN          90   2+ months
# 7            4  Moderate/Severe         None      NaN          96   2+ months
# 8            4  Moderate/Severe         None      NaN         110   2+ months
# 9            6  Moderate/Severe       Strong      NaN           7    Neonates
# 10           6  Moderate/Severe       Strong      NaN          21    Neonates
# 11           6  Moderate/Severe       Strong      NaN          42  1-2 months
# 12           6  Moderate/Severe       Strong   41.659          56  1-2 months
# 13           6  Moderate/Severe       Strong   44.209          70   2+ months
# 14           6  Moderate/Severe       Strong      NaN          77   2+ months
# 15           6  Moderate/Severe       Strong      NaN          84   2+ months
# 16           6  Moderate/Severe       Strong   41.451         100   2+ months
# 17           7  Moderate/Severe         None      NaN           7    Neonates
# 18           7  Moderate/Severe         None      NaN          25    Neonates
# 19           7  Moderate/Severe         None      NaN          43  1-2 months
#
#     days_since_first_wp  Unvaccinated  Recently Vaccinated  Vaccinated
# 0                   NaN          True                False       False
# 1                   NaN          True                False       False
# 2                   0.0          True                False       False
# 3                  14.0         False                 True       False
# 4                  21.0         False                 True       False
# 5                  30.0         False                False        True
# 6                  48.0         False                False        True
# 7                  54.0         False                False        True
# 8                  68.0         False                False        True
# 9                   NaN          True                False       False
# 10                  NaN          True                False       False
# 11                  0.0          True                False       False
# 12                 14.0         False                 True       False
# 13                 28.0         False                 True       False
# 14                 35.0         False                False        True
# 15                 42.0         False                False        True
# 16                 58.0         False                False        True
# 17                  NaN          True                False       False
# 18                  NaN          True                False       False
# 19                  0.0          True                False       False

# %%
final.to_excel('efi_np_final.xlsx', index=False)

# %%
final['Vaccinated'].value_counts()
# Out:
# Vaccinated
# False    5653
# True     3070
# Name: count, dtype: int64

# %%
final['Unvaccinated'].value_counts()
# Out:
# Unvaccinated
# True     4405
# False    4318
# Name: count, dtype: int64

# %%
final['Recently Vaccinated'].value_counts()
# Out:
# Recently Vaccinated
# False    7475
# True     1248
# Name: count, dtype: int64

# %%
final['Vaccinated'].unique()
# Out:
# array([False,  True])

# %%
final['fsymptom'] = pd.Categorical(
    final['fsymptom'],
    categories=['None', 'Minimal', 'Moderate/Severe'],
    ordered=True
)

# %%
vaccinated_df = (
    final[final["Vaccinated"] == True]
    .groupby("subject_id", as_index=False)
    .first()
)

# %%
vaccinated_df.shape
# Out:
# (1176, 10)

# %%
table_vax = pd.crosstab(vaccinated_df["fsymptom"], vaccinated_df["efi.strength"], margins=True, margins_name='Sum')
print(table_vax)
# Out:
# efi.strength     None  Strong  Weak   Sum
# fsymptom
# None              365      36    89   490
# Minimal           283      92   125   500
# Moderate/Severe    93      40    53   186
# Sum               741     168   267  1176

# %%
excluded_df = final[(final['Vaccinated'] == False) & (final['Unvaccinated'] == False)]
excluded_df.shape
# Out:
# (1248, 10)

# %%
base_df = final[final["Vaccinated"] == False].copy()
base_df.shape
# Out:
# (5653, 10)

# %%
# Now select only the recently vaccinated from this filtered data
recently_df = (
    base_df[base_df["Recently Vaccinated"] == True]
    .groupby("subject_id", as_index=False)
    .first()
    .copy()
)

recently_df.shape
# Out:
# (1129, 10)

# %%
excluded_df.head()
# Out:
#     subject_id         fsymptom efi.strength  ct_mean  infant_age   age_group  \
# 3            4  Moderate/Severe         None      NaN          56  1-2 months
# 4            4  Moderate/Severe         None      NaN          63   2+ months
# 12           6  Moderate/Severe       Strong   41.659          56  1-2 months
# 13           6  Moderate/Severe       Strong   44.209          70   2+ months
# 20           7  Moderate/Severe         None      NaN          57  1-2 months
#
#     days_since_first_wp  Unvaccinated  Recently Vaccinated  Vaccinated
# 3                  14.0         False                 True       False
# 4                  21.0         False                 True       False
# 12                 14.0         False                 True       False
# 13                 28.0         False                 True       False
# 20                 14.0         False                 True       False

# %%
unvaccinated_df = final[
    ~final['subject_id'].isin(vaccinated_df['subject_id']) &
    ~final['subject_id'].isin(excluded_df['subject_id'])
].copy()

# %%
unvaccinated_df.shape
# Out:
# (1320, 12)

# %%
unvaccinated_df.head()
# Out:
#    subject_id         fsymptom efi.strength
# 0          57  Moderate/Severe         None
# 1          58          Minimal         None
# 2          71  Moderate/Severe         None
# 3          72          Minimal       Strong
# 4         238          Minimal         None

# %%
unvaccinated_df = (
    unvaccinated_df[['subject_id', 'fsymptom', 'efi.strength']]
    .drop_duplicates(subset='subject_id')
    .reset_index(drop=True)
)

# %%
unvaccinated_df.shape
# Out:
# (58, 3)

# %%
unvaccinated_df.head()
# Out:
#    subject_id         fsymptom efi.strength
# 0          57  Moderate/Severe         None
# 1          58          Minimal         None
# 2          71  Moderate/Severe         None
# 3          72          Minimal       Strong
# 4         238          Minimal         None

# %%
unvaccinated_df['fsymptom'] = unvaccinated_df['fsymptom'].fillna('None')
unvaccinated_df['efi.strength'] = unvaccinated_df['efi.strength'].fillna('None')

# %%
unvaccinated_df['fsymptom'] = pd.Categorical(
    unvaccinated_df['fsymptom'],
    categories=['None', 'Minimal', 'Moderate/Severe'],
    ordered=True
)

# %%
table_unvax = pd.crosstab(unvaccinated_df["fsymptom"], unvaccinated_df["efi.strength"], margins=True, margins_name='Sum')
print(table_unvax)
# Out:
# efi.strength     None  Strong  Weak  Sum
# fsymptom
# None               28       1     1   30
# Minimal            14       3     2   19
# Moderate/Severe     7       1     1    9
# Sum                49       5     4   58

# %%
unique_excluded = excluded_df[
    ~excluded_df['subject_id'].isin(vaccinated_df['subject_id']) &
    ~excluded_df['subject_id'].isin(unvaccinated_df['subject_id'])
][['subject_id', 'fsymptom', 'efi.strength']].drop_duplicates(subset='subject_id').reset_index(drop=True)
unique_excluded.shape
# Out:
# (84, 3)

# %%
unique_excluded.head(20)
# Out:
#     subject_id         fsymptom efi.strength
# 0           24              NaN          NaN
# 1           61              NaN          NaN
# 2           76              NaN          NaN
# 3          123              NaN          NaN
# 4          213              NaN          NaN
# 5          222              NaN       Strong
# 6          247              NaN          NaN
# 7          415          Minimal         Weak
# 8          416          Minimal          NaN
# 9          432  Moderate/Severe         Weak
# 10         441              NaN         Weak
# 11         483          Minimal          NaN
# 12         499              NaN          NaN
# 13         526              NaN          NaN
# 14         628              NaN          NaN
# 15         662          Minimal          NaN
# 16         697              NaN       Strong
# 17         708              NaN          NaN
# 18         756          Minimal          NaN
# 19         845              NaN         Weak

# %%
unique_excluded['fsymptom'] = unique_excluded['fsymptom'].fillna('None')
unique_excluded['efi.strength'] = unique_excluded['efi.strength'].fillna('None')

# %%
unique_excluded['fsymptom'] = pd.Categorical(
   unique_excluded['fsymptom'],
    categories=['None', 'Minimal', 'Moderate/Severe'],
    ordered=True
)

# %%
for df in [vaccinated_df, unvaccinated_df, unique_excluded]:
    df['efi.strength'] = pd.Categorical(
        df['efi.strength'],
        categories=['None', 'Weak', 'Strong'],
        ordered=True
    )

# %%
table_excluded = pd.crosstab(unique_excluded["fsymptom"], unique_excluded["efi.strength"], margins=True, margins_name='Sum')
print(table_excluded)
# Out:
# efi.strength     None  Weak  Strong  Sum
# fsymptom
# None               53     3       3   59
# Minimal            15     1       0   16
# Moderate/Severe     8     1       0    9
# Sum                76     5       3   84

# %%
print(table_vax)
print(table_unvax)
# Out:
# efi.strength     None  Strong  Weak   Sum
# fsymptom
# None              365      37    89   491
# Minimal           283      92   125   500
# Moderate/Severe    93      40    54   187
# Sum               741     169   268  1178
# efi.strength     None  Strong  Weak  Sum
# fsymptom
# None               28       1     1   30
# Minimal            14       3     2   19
# Moderate/Severe     7       1     1    9
# Sum                49       5     4   58
